# %% [markdown]
# <a href="https://colab.research.google.com/github/ezpsumalapao31-maker/samplepythonactivities/blob/main/eze's_play_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

x1 = float(int(input("Enter x1:")))
x2 = float(int(input("Enter x2:")))
y1 = float(int(input("Enter y1:")))
y2 = float(int(input("Enter y2:")))

diff_x = x2 - x1
diff_y = y2 - y1

powered_x = pow(diff_x, 2)
powered_y = pow(diff_y, 2)

sum_x_y = "powered_x" + "powered_y"

print("sum_x_y")
# Out:
# Enter x1:2
# Enter x2:3
# Enter y1:4
# Enter y2:7
# sum_x_y
