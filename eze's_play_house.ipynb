# %% [markdown]
# <a href="https://colab.research.google.com/github/ezpsumalapao31-maker/samplepythonactivities/blob/main/eze's_play_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

x1 = float((input("Enter x1:")))
x2 = float((input("Enter x2:")))
y1 = float((input("Enter y1:")))
y2 = float((input("Enter y2:")))


distance = sqrt(pow(x2-x1, 2)pow(y2-y1, 2)2)
# Out:
#   File "/tmp/ipykernel_1321/1681697559.py", line 9
#     distance = sqrt(pow(x2-x1, 2)pow(y2-y1, 2)2)
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
